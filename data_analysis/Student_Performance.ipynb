# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataFrame = pd.read_csv('D:/project/Student_Performance.csv')
dataFrame
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
dataFrame.isna().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
sns.set_theme(style="dark")

# %%
(dataFrame.groupby('Hours Studied')
.agg({'Performance Index': 'mean'})
.plot
(
    ylabel = 'Performance',
    grid=True
))
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Performance'>

# %%
(dataFrame.groupby('Previous Scores')
.agg({'Performance Index': 'mean'})
.plot
(
    ylabel = 'Performance',
    grid=True
))
# Out:
# <Axes: xlabel='Previous Scores', ylabel='Performance'>

# %%
colors = plt.get_cmap('tab10').colors

grouped = dataFrame.groupby('Extracurricular Activities')['Performance Index'].mean()

ax = grouped.plot.bar(
    ylabel = 'Performance',
    grid=True,
    color = colors
)

labels = grouped.index.tolist()
handles = [plt.Rectangle((0,0),1,1, color=color) for color in colors]
ax.legend(handles, labels, title='Extracurricular Activities', bbox_to_anchor=(1,1))

plt.show()

# %%
(dataFrame.groupby('Sleep Hours')
.agg({'Performance Index': 'mean'})
.plot
(
    ylabel = 'Performance',
    grid=True
))
# Out:
# <Axes: xlabel='Sleep Hours', ylabel='Performance'>

# %%
(dataFrame.groupby('Sample Question Papers Practiced')
.agg({'Performance Index': 'mean'})
.plot.bar
(
    ylabel = 'Performance',
    grid=True
).legend(bbox_to_anchor=(1,1)))
